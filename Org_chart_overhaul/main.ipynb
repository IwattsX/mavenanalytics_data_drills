# %%
import pandas as pd
import math
from collections import defaultdict

# %%
office_df = pd.read_csv("OfficeSpace.csv")
office_df.rename(columns={"Employee Name" : "Employee", "Manager Name" : "Manager"}, inplace=True)
office_df
# Out:
#                Employee              Manager
# 0         Bill Lumbergh                  NaN
# 1           Bob Slydell        Bill Lumbergh
# 2            Bob Porter        Bill Lumbergh
# 3      Linda M. Grayson        Bill Lumbergh
# 4          Dom Portwood     Linda M. Grayson
# 5     Wendy L. Hargrove     Linda M. Grayson
# 6         Tom Smykowski     Linda M. Grayson
# 7        Nathan R. Ross     Linda M. Grayson
# 8         Peter Gibbons         Dom Portwood
# 9    Cheryl T. Ackerman        Peter Gibbons
# 10  Samir Nagheenanajar         Dom Portwood
# 11       Michael Bolton  Samir Nagheenanajar
# 12     Nathan C. Carter         Dom Portwood
# 13        Lydia Bennett     Nathan C. Carter
# 14       Greg S. Torres     Nathan C. Carter
# 15      Alice L. Munroe     Nathan C. Carter
# 16        Peggy Carlson    Wendy L. Hargrove
# 17        Anne Martinez    Wendy L. Hargrove
# 18       Fred Wilkinson    Wendy L. Hargrove
# 19    Derek P. Phillips        Tom Smykowski
# 20      Sarah J. Greene    Derek P. Phillips
# 21     Alan B. Peterson       Nathan R. Ross
# 22     Maria D. Sanchez     Alan B. Peterson
# 23    Bobbie K. Jenkins     Alan B. Peterson
# 24       Milton Waddams        Tom Smykowski

# %%
office_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Employee  25 non-null     object
#  1   Manager   24 non-null     object
# dtypes: object(2)
# memory usage: 532.0+ bytes

# %%
employee_to_managers = dict()
manager_to_employee = defaultdict(list)

for s in office_df.itertuples():
    manager = s.Manager
    employee = s.Employee
    if isinstance(manager, float) and math.isnan(manager):
        employee_to_managers[employee] = None 
    else:
        employee_to_managers[employee] = manager
        manager_to_employee[manager].append(employee)

employee_to_managers
print(manager_to_employee)
# Out:
# defaultdict(<class 'list'>, {'Bill Lumbergh': ['Bob Slydell', 'Bob Porter', 'Linda M. Grayson'], 'Linda M. Grayson': ['Dom Portwood', 'Wendy L. Hargrove', 'Tom Smykowski', 'Nathan R. Ross'], 'Dom Portwood': ['Peter Gibbons', 'Samir Nagheenanajar', 'Nathan C. Carter'], 'Peter Gibbons': ['Cheryl T. Ackerman'], 'Samir Nagheenanajar': ['Michael Bolton'], 'Nathan C. Carter': ['Lydia Bennett', 'Greg S. Torres', 'Alice L. Munroe'], 'Wendy L. Hargrove': ['Peggy Carlson', 'Anne Martinez', 'Fred Wilkinson'], 'Tom Smykowski': ['Derek P. Phillips', 'Milton Waddams'], 'Derek P. Phillips': ['Sarah J. Greene'], 'Nathan R. Ross': ['Alan B. Peterson'], 'Alan B. Peterson': ['Maria D. Sanchez', 'Bobbie K. Jenkins']})

# %%
office_df['Direct Reports'] = office_df["Employee"].apply(lambda x: len(manager_to_employee[x]))
office_df
# Out:
#                Employee              Manager  Direct Reports
# 0         Bill Lumbergh                  NaN               3
# 1           Bob Slydell        Bill Lumbergh               0
# 2            Bob Porter        Bill Lumbergh               0
# 3      Linda M. Grayson        Bill Lumbergh               4
# 4          Dom Portwood     Linda M. Grayson               3
# 5     Wendy L. Hargrove     Linda M. Grayson               3
# 6         Tom Smykowski     Linda M. Grayson               2
# 7        Nathan R. Ross     Linda M. Grayson               1
# 8         Peter Gibbons         Dom Portwood               1
# 9    Cheryl T. Ackerman        Peter Gibbons               0
# 10  Samir Nagheenanajar         Dom Portwood               1
# 11       Michael Bolton  Samir Nagheenanajar               0
# 12     Nathan C. Carter         Dom Portwood               3
# 13        Lydia Bennett     Nathan C. Carter               0
# 14       Greg S. Torres     Nathan C. Carter               0
# 15      Alice L. Munroe     Nathan C. Carter               0
# 16        Peggy Carlson    Wendy L. Hargrove               0
# 17        Anne Martinez    Wendy L. Hargrove               0
# 18       Fred Wilkinson    Wendy L. Hargrove               0
# 19    Derek P. Phillips        Tom Smykowski               1
# 20      Sarah J. Greene    Derek P. Phillips               0
# 21     Alan B. Peterson       Nathan R. Ross               2
# 22     Maria D. Sanchez     Alan B. Peterson               0
# 23    Bobbie K. Jenkins     Alan B. Peterson               0
# 24       Milton Waddams        Tom Smykowski               0

# %%
def get_total_reports(employee: str, manager_to_employee: dict):
    if len(manager_to_employee[employee]) == 0:
        return 0
    total = len(manager_to_employee[employee])
    for reporter in manager_to_employee[employee]:
        total += get_total_reports(reporter, manager_to_employee)
    return total

# Apply it to the DataFrame
office_df["Total Reports"] = office_df.apply(
    lambda x: get_total_reports(x["Employee"], manager_to_employee),
    axis=1
)

office_df
# Out:
#                Employee              Manager  Direct Reports  Total Reports
# 0         Bill Lumbergh                  NaN               3             24
# 1           Bob Slydell        Bill Lumbergh               0              0
# 2            Bob Porter        Bill Lumbergh               0              0
# 3      Linda M. Grayson        Bill Lumbergh               4             21
# 4          Dom Portwood     Linda M. Grayson               3              8
# 5     Wendy L. Hargrove     Linda M. Grayson               3              3
# 6         Tom Smykowski     Linda M. Grayson               2              3
# 7        Nathan R. Ross     Linda M. Grayson               1              3
# 8         Peter Gibbons         Dom Portwood               1              1
# 9    Cheryl T. Ackerman        Peter Gibbons               0              0
# 10  Samir Nagheenanajar         Dom Portwood               1              1
# 11       Michael Bolton  Samir Nagheenanajar               0              0
# 12     Nathan C. Carter         Dom Portwood               3              3
# 13        Lydia Bennett     Nathan C. Carter               0              0
# 14       Greg S. Torres     Nathan C. Carter               0              0
# 15      Alice L. Munroe     Nathan C. Carter               0              0
# 16        Peggy Carlson    Wendy L. Hargrove               0              0
# 17        Anne Martinez    Wendy L. Hargrove               0              0
# 18       Fred Wilkinson    Wendy L. Hargrove               0              0
# 19    Derek P. Phillips        Tom Smykowski               1              1
# 20      Sarah J. Greene    Derek P. Phillips               0              0
# 21     Alan B. Peterson       Nathan R. Ross               2              2
# 22     Maria D. Sanchez     Alan B. Peterson               0              0
# 23    Bobbie K. Jenkins     Alan B. Peterson               0              0
# 24       Milton Waddams        Tom Smykowski               0              0

# %%
def hierarchy_data(employee_to_managers : dict, employee):
    manager = employee_to_managers.get(employee)
    if manager is None:
        return employee
    ans = []
    ans.append(employee)
    while manager is not None:
        ans.append(manager)
        manager = employee_to_managers[manager]
    ans[:] = ans[::-1]
    return " > ".join(ans)

# %%
office_df["Reporting Hierarchy"] = office_df.apply(lambda x: hierarchy_data(employee_to_managers, x.Employee), axis=1)
office_df
# Out:
#                Employee              Manager  Direct Reports  Total Reports  \
# 0         Bill Lumbergh                  NaN               3             24
# 1           Bob Slydell        Bill Lumbergh               0              0
# 2            Bob Porter        Bill Lumbergh               0              0
# 3      Linda M. Grayson        Bill Lumbergh               4             21
# 4          Dom Portwood     Linda M. Grayson               3              8
# 5     Wendy L. Hargrove     Linda M. Grayson               3              3
# 6         Tom Smykowski     Linda M. Grayson               2              3
# 7        Nathan R. Ross     Linda M. Grayson               1              3
# 8         Peter Gibbons         Dom Portwood               1              1
# 9    Cheryl T. Ackerman        Peter Gibbons               0              0
# 10  Samir Nagheenanajar         Dom Portwood               1              1
# 11       Michael Bolton  Samir Nagheenanajar               0              0
# 12     Nathan C. Carter         Dom Portwood               3              3
# 13        Lydia Bennett     Nathan C. Carter               0              0
# 14       Greg S. Torres     Nathan C. Carter               0              0
# 15      Alice L. Munroe     Nathan C. Carter               0              0
# 16        Peggy Carlson    Wendy L. Hargrove               0              0
# 17        Anne Martinez    Wendy L. Hargrove               0              0
# 18       Fred Wilkinson    Wendy L. Hargrove               0              0
# 19    Derek P. Phillips        Tom Smykowski               1              1
# 20      Sarah J. Greene    Derek P. Phillips               0              0
# 21     Alan B. Peterson       Nathan R. Ross               2              2
# 22     Maria D. Sanchez     Alan B. Peterson               0              0
# 23    Bobbie K. Jenkins     Alan B. Peterson               0              0
# 24       Milton Waddams        Tom Smykowski               0              0
#
#                                   Reporting Hierarchy
# 0                                       Bill Lumbergh
# 1                         Bill Lumbergh > Bob Slydell
# 2                          Bill Lumbergh > Bob Porter
# 3                    Bill Lumbergh > Linda M. Grayson
# 4     Bill Lumbergh > Linda M. Grayson > Dom Portwood
# 5   Bill Lumbergh > Linda M. Grayson > Wendy L. Ha...
# 6    Bill Lumbergh > Linda M. Grayson > Tom Smykowski
# 7   Bill Lumbergh > Linda M. Grayson > Nathan R. Ross
# 8   Bill Lumbergh > Linda M. Grayson > Dom Portwoo...
# 9   Bill Lumbergh > Linda M. Grayson > Dom Portwoo...
# 10  Bill Lumbergh > Linda M. Grayson > Dom Portwoo...
# 11  Bill Lumbergh > Linda M. Grayson > Dom Portwoo...
# 12  Bill Lumbergh > Linda M. Grayson > Dom Portwoo...
# 13  Bill Lumbergh > Linda M. Grayson > Dom Portwoo...
# 14  Bill Lumbergh > Linda M. Grayson > Dom Portwoo...
# 15  Bill Lumbergh > Linda M. Grayson > Dom Portwoo...
# 16  Bill Lumbergh > Linda M. Grayson > Wendy L. Ha...
# 17  Bill Lumbergh > Linda M. Grayson > Wendy L. Ha...
# 18  Bill Lumbergh > Linda M. Grayson > Wendy L. Ha...
# 19  Bill Lumbergh > Linda M. Grayson > Tom Smykows...
# 20  Bill Lumbergh > Linda M. Grayson > Tom Smykows...
# 21  Bill Lumbergh > Linda M. Grayson > Nathan R. R...
# 22  Bill Lumbergh > Linda M. Grayson > Nathan R. R...
# 23  Bill Lumbergh > Linda M. Grayson > Nathan R. R...
# 24  Bill Lumbergh > Linda M. Grayson > Tom Smykows...

# %%
total_reports = office_df["Total Reports"].sum().sum()
total_reports
# Out:
# 70
